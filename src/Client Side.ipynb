# %% [markdown]
# # Client Side
#
# * ### Encrypt transaction datapoint
# * ### Send to server for inference
# * ### Decrypt response

# %% [markdown]
# ## XGBoost endpoint for ULB dataset

# %%
# %run client.py --dataset=ulb --model=xgboost
# Out:
# Loading ulb dataset...
#
#
# Test input:
#             Time        V1        V2        V3        V4        V5        V6  \
# 268444  163214.0 -1.248321  1.997575 -0.544809 -0.860984  0.529701 -1.190311
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 268444  1.367489 -0.615384  1.662114  ...  1.006743  0.060228  1.223803
#
#              V23       V24      V25       V26       V27       V28  Amount
# 268444 -0.118718 -0.082649 -0.49977 -0.236825  0.916828  0.296307    0.79
#
# [1 rows x 30 columns]
# Expected result: 0
#
# Loading keys from ./client-files/encrypted-ulb-xgboost-keys.pt
#
# Encrypted input:
#         qG8cnKlCg3T18240V0wX2LCCyYbOJbZKiT20RT0OnBo=  \
# 268444                                  8.712449e+18
#
#         tef8D2m3ceAz514jKse6bpAZIOgIlylpcGS4KrGsVoE=  \
# 268444                                  6.000976e+15
#
#         DDSPSbmfIj6z80sA8U9ZWgKxhGIZSeq18S837oMg89o=  \
# 268444                                  6.174140e+15
#
# ...

# %% [markdown]
# ## Ensuring selected transaction is fraudulant

# %%
# %run client.py --dataset=ulb --model=xgboost --fraudulant
# Out:
# Loading ulb dataset...
#
#
# Test input:
#             Time        V1        V2        V3        V4        V5        V6  \
# 262560  160537.0  0.567539  3.309385 -6.631268  6.394574 -0.054172 -2.396535
#
#               V7        V8       V9  ...       V20       V21       V22  \
# 262560 -2.792489  0.514811 -3.54178  ...  0.555412  0.614221 -0.365047
#
#              V23       V24       V25       V26       V27       V28  Amount
# 262560 -0.180409 -0.523271  0.645054  0.246466  0.902675  0.473571    4.69
#
# [1 rows x 30 columns]
# Expected result: 1
#
# Loading keys from ./client-files/encrypted-ulb-xgboost-keys.pt
#
# Encrypted input:
#         qG8cnKlCg3T18240V0wX2LCCyYbOJbZKiT20RT0OnBo=  \
# 262560                                  8.569650e+18
#
#         tef8D2m3ceAz514jKse6bpAZIOgIlylpcGS4KrGsVoE=  \
# 262560                                  6.097848e+15
#
#         DDSPSbmfIj6z80sA8U9ZWgKxhGIZSeq18S837oMg89o=  \
# 262560                                  6.244103e+15
#
# ...

# %% [markdown]
# ## Neural Network endpoint for ULB Dataset

# %%
# %run client.py --dataset=ulb --model=nn --fraudulant
# Out:
# Loading ulb dataset...
#
#
# Test input:
#             Time        V1       V2        V3        V4        V5        V6  \
# 254395  156710.0  0.202402  1.17627  0.346379  2.882138  1.407133 -0.504355
#
#               V7        V8        V9  ...       V20      V21      V22  \
# 254395  1.438537 -0.395603 -1.555142  ... -0.206239  0.24256  0.84123
#
#              V23       V24       V25       V26       V27       V28  Amount
# 254395 -0.370157 -0.026012  0.491954  0.234576 -0.279788 -0.331933    7.59
#
# [1 rows x 30 columns]
# Expected result: 1
#
# Encrypted input:
# ...
#
# Sending encrypted input to http://134.226.86.101:8000/nn/ulb
#
# Received encrypted result:
# ...
#
# Decrypted result: 0
# Which is incorrect.
# Time taken from encryption of input to decryption of result: 0 mins, 3 seconds, 871 ms

# %% [markdown]
# ## XGBoost endpoint for IEEE dataset

# %%
# %run client.py --dataset=ieee --model=xgboost --fraudulant
# Out:
# Loading ieee dataset...
#
#
# Test input:
#                TransactionDT  TransactionAmt  ProductCD  card1  card2  card3  \
# TransactionID
# 3557572             15136042           500.0          2  16075  514.0  150.0
#
#                card4  card5  card6  addr1  ...  id_31  id_32  id_33  id_34  \
# TransactionID                              ...
# 3557572            3  102.0      2  264.0  ...     38   32.0     37      4
#
#                id_35  id_36  id_37  id_38  DeviceType  DeviceInfo
# TransactionID
# 3557572            2      1      2      1           2        1699
#
# [1 rows x 432 columns]
# Expected result: 1
#
# Loading keys from ./client-files/encrypted-ieee-xgboost-keys.pt
#
# Encrypted input:
#                43HEV9dMEh5WMXhD6FL4mRHMHS6ZfolL3dXs9MZMlto=  \
# TransactionID
# 3557572                                 8829585730080037046
#
#                IASd7mJO4idCcyGc8PAmOFTkKSQawOuvgYSRLaK0mWw=  \
# TransactionID
# ...
